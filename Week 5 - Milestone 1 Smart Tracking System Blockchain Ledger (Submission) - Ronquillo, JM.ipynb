# %%
import pandas as pd
import time
from web3 import Web3

# --- Setup web3 and contract (example) ---
# Replace with my actual provider URL and contract details
provider_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(provider_url))

if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")


# Set my default account (replace with my account)
web3.eth.default_account = web3.eth.accounts[0]  # or use private key management

# Replace with my contract ABI and address
contract_abi = [
	{
		"anonymous": False,
		"inputs": [
			{
				"indexed": False,
				"internalType": "string",
				"name": "vehicleID",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "latitude",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "longitude",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "speed_kmph",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "battery_percent",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			}
		],
		"name": "DataStored",
		"type": "event"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "_vehicleID",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_latitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_longitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_speed_kmph",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_battery_percent",
				"type": "string"
			}
		],
		"name": "storeData",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "index",
				"type": "uint256"
			}
		],
		"name": "getRecord",
		"outputs": [
			{
				"internalType": "string",
				"name": "vehicleID",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "latitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "longitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "speed_kmph",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "battery_percent",
				"type": "string"
			},
			{
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "getRecordCount",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	}
]  # my contract ABI here
contract_address = "0xd40660925A19c8E0C8cA8905E0E4b2658957536F"
contract = web3.eth.contract(address=contract_address, abi=contract_abi)

print(f"✅ Connected to Smart Contract at {contract_address}")

# --- Load my CSV data ---
df = pd.read_csv('vehicle_tracking_data.csv')

print("Columns in DataFrame:", df.columns)

# Optional: Check required columns and set defaults if missing
required_columns = ['vehicle_id', 'latitude', 'longitude', 'speed_kmph', 'battery_percent']

for col in required_columns:
    if col not in df.columns:
        print(f"Warning: Missing column '{col}' in data. Filling with default values.")
        if col in ['vehicle_id']:
            df[col] = 'unknown'
        else:
            df[col] = 0  # numeric default

# --- Function to send data to smart contract ---
def send_vehicle_data(row):
    try:
        txn = contract.functions.storeData(
            str(row["vehicle_id"]),
            str(row["latitude"]),
            str(row["longitude"]),
            str(row["speed_kmph"]),
            str(row["battery_percent"])
        ).transact({'from': web3.eth.default_account, 'gas': 3000000})

        receipt = web3.eth.wait_for_transaction_receipt(txn)
        print(f"✅ Stored for {row['vehicle_id']} | Txn Hash: {receipt.transactionHash.hex()}")
    except Exception as e:
        print(f"❌ Failed to store data for {row.get('vehicle_id', 'unknown')}: {e}")

# --- Loop through rows and send data ---
for _, row in df.iterrows():
    send_vehicle_data(row)
    time.sleep(1)  # delay to avoid spamming the network

total = contract.functions.getRecordCount().call()
print(f"📦 Total records stored in contract: {total}")
# Out:
# ✅ Connected to Ganache successfully!
# ✅ Connected to Smart Contract at 0xd40660925A19c8E0C8cA8905E0E4b2658957536F
# Columns in DataFrame: Index(['vehicle_id', 'timestamp', 'latitude', 'longitude', 'speed_kmph',
#        'battery_percent'],
#       dtype='object')
# ✅ Stored for 1 | Txn Hash: 890a8fd5bee40e0b9610b89d8d80124fadd3fb0f4dd626d3b67e21f6217862ae
# ✅ Stored for 2 | Txn Hash: dc9e5f566d80860d7fa5594538cab3a5a3bf3f4aab958d573fcc72703f46310d
# ✅ Stored for 3 | Txn Hash: 12deb637eec2c894d9b43164f91f18138911d0284ce9ec42d14c0e158af293e3
# ✅ Stored for 4 | Txn Hash: 9398ca3d28fbc2adcf5bed1f10f544c74e7fe4a3465a181f75e36f70ee6546e3
# ✅ Stored for 5 | Txn Hash: d6dbb7a64343b2060722d8bf0713679db030e5a2eae74fc28f970b9ffc571e34
# ✅ Stored for 6 | Txn Hash: 9949f21d7e498c096743a7647c94959f0b7ea80136456d5bd4d41600a806d3ec
# ✅ Stored for 128 | Txn Hash: 5d31ac44ab6214a4834e14570fd5add00b699671e74915f94efd9f647e1f49b2
# ✅ Stored for 129 | Txn Hash: 2b0027bc04a908d66de369181146c901223be5c733966a6c458781e44edfa52f
# ✅ Stored for 130 | Txn Hash: 04e99d04750cf0ead59addc333b40d4904c8bd258caf842e8e0021616386c045
# ✅ Stored for 131 | Txn Hash: a7df0e0e3fd4946369162069f618161b3475c2d42592ce6096bb78c13c73c1bf
# ✅ Stored for 132 | Txn Hash: 8cb8aa152e642bc9ac370a9374b7732c8a8c64776fb8cdc917c1dc4ce2a6d544
# ✅ Stored for 133 | Txn Hash: ae1e0fa3a698e20590b7692b468dcdec87e08a22dc933c77dc0eef2151dd6f56
# ✅ Stored for 134 | Txn Hash: dd7af989d2dc289b7f1a64ceaf340340c18ada6d4a880bfb5c10afb7aeab246c
# ✅ Stored for 135 | Txn Hash: 241b833150bae7d0a8fad57a317586a3fe67ce25e944d95c52aee32dd78617b6
# ✅ Stored for 136 | Txn Hash: 46166194426ff3ea9949a3e05fcacf077de5ede776b04364e759c3e0fb121e57
# ✅ Stored for 137 | Txn Hash: 76d5da26809b80c833fdb4269e5d865ce94538ac36b3c7aaaf691a7050d8a51b
# ✅ Stored for 138 | Txn Hash: 3b3b125b51457dd6164350286fae42bd2fdc91605bf0ee4682e7864c2ea6eecc
# ✅ Stored for 139 | Txn Hash: 682e14301c0235db4ba29817e93cb243f11ac1b18c07edf193278198a75b131c
# ✅ Stored for 140 | Txn Hash: 42ea74fc0f40688c4066d23135e1f8209345edefcd09abc6f1b35018a258ae9c
# ✅ Stored for 141 | Txn Hash: 1a8d07fcece05ea2faf74e5c2352c0bde3b012c9ca701aa5898e1d1a4aef7724
# ✅ Stored for 142 | Txn Hash: 97317e2d29757625c1e62bfb2cdd06ad60e393ededf2c100a4ed2818b9633a54
# ✅ Stored for 143 | Txn Hash: fca3bf3d44a0243192fdd1f0c63b789ef3dbc3f321fc3b7d7bcd1520e81e33f3
# ✅ Stored for 144 | Txn Hash: 49db74fcadd6cdf68abde88f1a7c19cff5be73ecc7113f3ef537948ee1965709
# ✅ Stored for 145 | Txn Hash: b0dadf701af4b87675887114c4f17633ad0135ea65d669b152b48f64b8668d31
# ✅ Stored for 146 | Txn Hash: dba1831bc310084cf0f67668ecd2e2c082a335c356ba73a19459325c82950d0e
# ✅ Stored for 147 | Txn Hash: fa1a3a3c2ec11d1612c25d48bf05e29cdd9422d26514be49dc7feb16864eb392
# ✅ Stored for 148 | Txn Hash: 0c5766531fc148a419e7bba4670af77b01f427ff924d2a8fb598dd80ccc07ccb
# ✅ Stored for 149 | Txn Hash: b5b3b0a2c7c96b03e9fa1128a9b806906995d20a3c969f15234ad18788a26418
# ✅ Stored for 150 | Txn Hash: 464096c0d604708aa589dacfea8ff5e505892186e3ff2eb81ba67e5cd1c8a2a5
# 📦 Total records stored in contract: 150

# %%
# Print all function names available in the contract
for func in contract.functions:
    print(func.fn_name)
# Out:
# getRecord
# getRecordCount
# storeData

# %%
# Get the total number of records from the smart contract
total_records = contract.functions.getRecordCount().call()

# Display the first 5 stored records
for i in range(min(5, total_records)):
    record = contract.functions.getRecord(i).call()
    print(f"\nRecord {i + 1}:")
    print(f"  Vehicle ID   : {record[0]}")
    print(f"  Location     : ({record[1]}, {record[2]})")
    print(f"  Speed (km/h) : {record[3]}")
    print(f"  Battery (%)  : {record[4]}")
    print(f"  Timestamp    : {record[5]}")
# Out:
# Record 1:
#   Vehicle ID   : 1
#   Location     : (14.599986, 120.984765)
#   Speed (km/h) : 44.97
#   Battery (%)  : 99.92
#   Timestamp    : 1748847771
#
# Record 2:
#   Vehicle ID   : 2
#   Location     : (14.600463, 120.985423)
#   Speed (km/h) : 37.66
#   Battery (%)  : 99.85
#   Timestamp    : 1748847773
#
# Record 3:
#   Vehicle ID   : 3
#   Location     : (14.601017, 120.985876)
#   Speed (km/h) : 35.31
#   Battery (%)  : 99.81
#   Timestamp    : 1748847774
#
# Record 4:
#   Vehicle ID   : 4
#   Location     : (14.601326, 120.986204)
#   Speed (km/h) : 42.42
#   Battery (%)  : 99.77
#   Timestamp    : 1748847775
#
# Record 5:
#   Vehicle ID   : 5
#   Location     : (14.601857, 120.986613)
#   Speed (km/h) : 29.87
#   Battery (%)  : 99.75
#   Timestamp    : 1748847776

# %%
# Get the total number of records from the smart contract
total_records = contract.functions.getRecordCount().call()

# Display all stored records
for i in range(total_records):
    record = contract.functions.getRecord(i).call()
    print(f"\nRecord {i + 1}:")
    print(f"  Vehicle ID   : {record[0]}")
    print(f"  Location     : ({record[1]}, {record[2]})")
    print(f"  Speed (km/h) : {record[3]}")
    print(f"  Battery (%)  : {record[4]}")
    print(f"  Timestamp    : {record[5]}")
# Out:
# Record 1:
#   Vehicle ID   : 1
#   Location     : (14.599986, 120.984765)
#   Speed (km/h) : 44.97
#   Battery (%)  : 99.92
#   Timestamp    : 1748847771
#
# Record 2:
#   Vehicle ID   : 2
#   Location     : (14.600463, 120.985423)
#   Speed (km/h) : 37.66
#   Battery (%)  : 99.85
#   Timestamp    : 1748847773
#
# Record 3:
#   Vehicle ID   : 3
#   Location     : (14.601017, 120.985876)
#   Speed (km/h) : 35.31
#   Battery (%)  : 99.81
#   Timestamp    : 1748847774
#
# Record 4:
#   Vehicle ID   : 4
#   Location     : (14.601326, 120.986204)
#   Speed (km/h) : 42.42
#   Battery (%)  : 99.77
#   Timestamp    : 1748847775
#
# Record 5:
#   Vehicle ID   : 5
#   Location     : (14.601857, 120.986613)
#   Speed (km/h) : 29.87
#   Battery (%)  : 99.75
#   Timestamp    : 1748847776
#
# Record 6:
#   Vehicle ID   : 6
#   Location     : (14.602335, 120.98712)
#   Speed (km/h) : 54.66
#   Battery (%)  : 99.73
#   Timestamp    : 1748847777
#
# Record 7:
#   Vehicle ID   : 7
#   Location     : (14.602846, 120.987505)
#   Speed (km/h) : 34.56
#   Battery (%)  : 99.67
#   Timestamp    : 1748847778
#
# Record 8:
#   Vehicle ID   : 8
#   Location     : (14.603316, 120.987945)
#   Speed (km/h) : 33.99
#   Battery (%)  : 99.59
#   Timestamp    : 1748847779
#
# Record 9:
#   Vehicle ID   : 9
#   Location     : (14.603711, 120.988527)
#   Speed (km/h) : 39.87
#   Battery (%)  : 99.56
#   Timestamp    : 1748847780
#
# Record 10:
#   Vehicle ID   : 10
#   Location     : (14.604015, 120.988894)
#   Speed (km/h) : 42.09
#   Battery (%)  : 99.51
#   Timestamp    : 1748847781
#
# Record 11:
#   Vehicle ID   : 11
#   Location     : (14.604532, 120.989382)
#   Speed (km/h) : 47.38
#   Battery (%)  : 99.46
#   Timestamp    : 1748847782
#
# Record 12:
#   Vehicle ID   : 12
#   Location     : (14.60496, 120.989836)
#   Speed (km/h) : 25.21
#   Battery (%)  : 99.39
#   Timestamp    : 1748847783
#
# Record 13:
#   Vehicle ID   : 13
#   Location     : (14.605284, 120.990369)
#   Speed (km/h) : 43.44
#   Battery (%)  : 99.35
#   Timestamp    : 1748847784
#
# Record 14:
#   Vehicle ID   : 14
#   Location     : (14.605845, 120.990972)
#   Speed (km/h) : 33.23
#   Battery (%)  : 99.28
#   Timestamp    : 1748847785
#
# Record 15:
#   Vehicle ID   : 15
#   Location     : (14.606314, 120.991505)
#   Speed (km/h) : 31.61
#   Battery (%)  : 99.21
#   Timestamp    : 1748847786
#
# Record 16:
#   Vehicle ID   : 16
#   Location     : (14.606795, 120.991894)
#   Speed (km/h) : 35.21
#   Battery (%)  : 99.19
#   Timestamp    : 1748847787
#
# Record 17:
#   Vehicle ID   : 17
#   Location     : (14.607431, 120.992387)
#   Speed (km/h) : 48.13
#   Battery (%)  : 99.12
#   Timestamp    : 1748847788
#
# Record 18:
#   Vehicle ID   : 18
#   Location     : (14.607866, 120.992923)
#   Speed (km/h) : 43.62
#   Battery (%)  : 99.03
#   Timestamp    : 1748847789
#
# Record 19:
#   Vehicle ID   : 19
#   Location     : (14.608523, 120.993161)
#   Speed (km/h) : 39.64
#   Battery (%)  : 98.97
#   Timestamp    : 1748847790
#
# Record 20:
#   Vehicle ID   : 20
#   Location     : (14.608993, 120.99367)
#   Speed (km/h) : 40.87
#   Battery (%)  : 98.96
#   Timestamp    : 1748847791
#
# Record 21:
#   Vehicle ID   : 21
#   Location     : (14.609529, 120.994318)
#   Speed (km/h) : 37.8
#   Battery (%)  : 98.92
#   Timestamp    : 1748847792
#
# Record 22:
#   Vehicle ID   : 22
#   Location     : (14.609978, 120.99491)
#   Speed (km/h) : 31.92
#   Battery (%)  : 98.86
#   Timestamp    : 1748847793
#
# Record 23:
#   Vehicle ID   : 23
#   Location     : (14.61053, 120.99542)
#   Speed (km/h) : 34.7
#   Battery (%)  : 98.79
#   Timestamp    : 1748847795
#
# Record 24:
#   Vehicle ID   : 24
#   Location     : (14.610997, 120.99588)
#   Speed (km/h) : 32.98
#   Battery (%)  : 98.77
#   Timestamp    : 1748847796
#
# Record 25:
#   Vehicle ID   : 25
#   Location     : (14.611523, 120.996381)
#   Speed (km/h) : 42.96
#   Battery (%)  : 98.73
#   Timestamp    : 1748847797
#
# Record 26:
#   Vehicle ID   : 26
#   Location     : (14.611981, 120.996847)
#   Speed (km/h) : 25.85
#   Battery (%)  : 98.69
#   Timestamp    : 1748847798
#
# Record 27:
#   Vehicle ID   : 27
#   Location     : (14.612521, 120.997535)
#   Speed (km/h) : 38.39
#   Battery (%)  : 98.64
#   Timestamp    : 1748847799
#
# Record 28:
#   Vehicle ID   : 28
#   Location     : (14.613014, 120.997843)
#   Speed (km/h) : 42.58
#   Battery (%)  : 98.59
#   Timestamp    : 1748847800
#
# Record 29:
#   Vehicle ID   : 29
#   Location     : (14.61376, 120.998324)
#   Speed (km/h) : 40.6
#   Battery (%)  : 98.53
#   Timestamp    : 1748847801
#
# Record 30:
#   Vehicle ID   : 30
#   Location     : (14.614143, 120.998938)
#   Speed (km/h) : 39.65
#   Battery (%)  : 98.47
#   Timestamp    : 1748847802
#
# Record 31:
#   Vehicle ID   : 31
#   Location     : (14.614553, 120.999579)
#   Speed (km/h) : 47.91
#   Battery (%)  : 98.45
#   Timestamp    : 1748847803
#
# Record 32:
#   Vehicle ID   : 32
#   Location     : (14.615272, 120.99998)
#   Speed (km/h) : 45.87
#   Battery (%)  : 98.41
#   Timestamp    : 1748847804
#
# Record 33:
#   Vehicle ID   : 33
#   Location     : (14.615721, 121.000324)
#   Speed (km/h) : 41.0
#   Battery (%)  : 98.36
#   Timestamp    : 1748847805
#
# Record 34:
#   Vehicle ID   : 34
#   Location     : (14.616269, 121.000733)
#   Speed (km/h) : 29.38
#   Battery (%)  : 98.28
#   Timestamp    : 1748847806
#
# Record 35:
#   Vehicle ID   : 35
#   Location     : (14.616736, 121.001314)
#   Speed (km/h) : 32.17
#   Battery (%)  : 98.25
#   Timestamp    : 1748847807
#
# Record 36:
#   Vehicle ID   : 36
#   Location     : (14.617367, 121.001653)
#   Speed (km/h) : 42.27
#   Battery (%)  : 98.2
#   Timestamp    : 1748847808
#
# Record 37:
#   Vehicle ID   : 37
#   Location     : (14.617945, 121.002029)
#   Speed (km/h) : 42.6
#   Battery (%)  : 98.17
#   Timestamp    : 1748847809
#
# Record 38:
#   Vehicle ID   : 38
#   Location     : (14.618475, 121.002555)
#   Speed (km/h) : 45.22
#   Battery (%)  : 98.12
#   Timestamp    : 1748847811
#
# Record 39:
#   Vehicle ID   : 39
#   Location     : (14.618998, 121.003084)
#   Speed (km/h) : 33.2
#   Battery (%)  : 98.08
#   Timestamp    : 1748847812
#
# Record 40:
#   Vehicle ID   : 40
#   Location     : (14.619546, 121.003465)
#   Speed (km/h) : 58.66
#   Battery (%)  : 98.02
#   Timestamp    : 1748847813
#
# Record 41:
#   Vehicle ID   : 41
#   Location     : (14.620124, 121.004081)
#   Speed (km/h) : 30.25
#   Battery (%)  : 97.98
#   Timestamp    : 1748847814
#
# Record 42:
#   Vehicle ID   : 42
#   Location     : (14.620666, 121.004663)
#   Speed (km/h) : 49.63
#   Battery (%)  : 97.9
#   Timestamp    : 1748847815
#
# Record 43:
#   Vehicle ID   : 43
#   Location     : (14.62109, 121.005074)
#   Speed (km/h) : 37.55
#   Battery (%)  : 97.86
#   Timestamp    : 1748847816
#
# Record 44:
#   Vehicle ID   : 44
#   Location     : (14.621624, 121.005601)
#   Speed (km/h) : 39.23
#   Battery (%)  : 97.8
#   Timestamp    : 1748847817
#
# Record 45:
#   Vehicle ID   : 45
#   Location     : (14.62227, 121.006075)
#   Speed (km/h) : 40.13
#   Battery (%)  : 97.69
#   Timestamp    : 1748847818
#
# Record 46:
#   Vehicle ID   : 46
#   Location     : (14.622684, 121.006468)
#   Speed (km/h) : 46.26
#   Battery (%)  : 97.63
#   Timestamp    : 1748847819
#
# Record 47:
#   Vehicle ID   : 47
#   Location     : (14.623255, 121.007015)
#   Speed (km/h) : 37.77
#   Battery (%)  : 97.58
#   Timestamp    : 1748847820
#
# Record 48:
#   Vehicle ID   : 48
#   Location     : (14.623604, 121.007471)
#   Speed (km/h) : 31.53
#   Battery (%)  : 97.52
#   Timestamp    : 1748847821
#
# Record 49:
#   Vehicle ID   : 49
#   Location     : (14.623979, 121.007988)
#   Speed (km/h) : 42.14
#   Battery (%)  : 97.46
#   Timestamp    : 1748847822
#
# Record 50:
#   Vehicle ID   : 50
#   Location     : (14.624495, 121.008494)
#   Speed (km/h) : 31.16
#   Battery (%)  : 97.43
#   Timestamp    : 1748847823
#
# Record 51:
#   Vehicle ID   : 51
#   Location     : (14.625051, 121.009102)
#   Speed (km/h) : 43.58
#   Battery (%)  : 97.36
#   Timestamp    : 1748847824
#
# Record 52:
#   Vehicle ID   : 52
#   Location     : (14.625457, 121.009654)
#   Speed (km/h) : 26.22
#   Battery (%)  : 97.3
#   Timestamp    : 1748847825
#
# Record 53:
#   Vehicle ID   : 53
#   Location     : (14.626342, 121.010211)
#   Speed (km/h) : 45.15
#   Battery (%)  : 97.23
#   Timestamp    : 1748847826
#
# Record 54:
#   Vehicle ID   : 54
#   Location     : (14.626907, 121.010679)
#   Speed (km/h) : 49.54
#   Battery (%)  : 97.16
#   Timestamp    : 1748847827
#
# Record 55:
#   Vehicle ID   : 55
#   Location     : (14.627384, 121.011131)
#   Speed (km/h) : 32.27
#   Battery (%)  : 97.11
#   Timestamp    : 1748847828
#
# Record 56:
#   Vehicle ID   : 56
#   Location     : (14.627697, 121.011699)
#   Speed (km/h) : 63.15
#   Battery (%)  : 97.09
#   Timestamp    : 1748847829
#
# Record 57:
#   Vehicle ID   : 57
#   Location     : (14.628306, 121.012206)
#   Speed (km/h) : 35.28
#   Battery (%)  : 97.06
#   Timestamp    : 1748847831
#
# Record 58:
#   Vehicle ID   : 58
#   Location     : (14.628874, 121.012633)
#   Speed (km/h) : 32.85
#   Battery (%)  : 97.01
#   Timestamp    : 1748847832
#
# Record 59:
#   Vehicle ID   : 59
#   Location     : (14.629309, 121.013347)
#   Speed (km/h) : 40.46
#   Battery (%)  : 96.95
#   Timestamp    : 1748847833
#
# Record 60:
#   Vehicle ID   : 60
#   Location     : (14.629827, 121.013781)
#   Speed (km/h) : 19.75
#   Battery (%)  : 96.88
#   Timestamp    : 1748847834
#
# Record 61:
#   Vehicle ID   : 61
#   Location     : (14.630316, 121.014331)
#   Speed (km/h) : 32.07
#   Battery (%)  : 96.81
#   Timestamp    : 1748847835
#
# Record 62:
#   Vehicle ID   : 62
#   Location     : (14.630782, 121.014784)
#   Speed (km/h) : 28.0
#   Battery (%)  : 96.78
#   Timestamp    : 1748847836
#
# Record 63:
#   Vehicle ID   : 63
#   Location     : (14.631323, 121.015158)
#   Speed (km/h) : 57.65
#   Battery (%)  : 96.71
#   Timestamp    : 1748847837
#
# Record 64:
#   Vehicle ID   : 64
#   Location     : (14.631926, 121.015506)
#   Speed (km/h) : 61.22
#   Battery (%)  : 96.67
#   Timestamp    : 1748847838
#
# Record 65:
#   Vehicle ID   : 65
#   Location     : (14.632355, 121.01605)
#   Speed (km/h) : 52.67
#   Battery (%)  : 96.6
#   Timestamp    : 1748847839
#
# Record 66:
#   Vehicle ID   : 66
#   Location     : (14.632849, 121.016226)
#   Speed (km/h) : 30.73
#   Battery (%)  : 96.57
#   Timestamp    : 1748847840
#
# Record 67:
#   Vehicle ID   : 67
#   Location     : (14.633225, 121.016889)
#   Speed (km/h) : 37.47
#   Battery (%)  : 96.55
#   Timestamp    : 1748847841
#
# Record 68:
#   Vehicle ID   : 68
#   Location     : (14.633738, 121.017533)
#   Speed (km/h) : 35.6
#   Battery (%)  : 96.53
#   Timestamp    : 1748847842
#
# Record 69:
#   Vehicle ID   : 69
#   Location     : (14.634239, 121.017935)
#   Speed (km/h) : 51.63
#   Battery (%)  : 96.47
#   Timestamp    : 1748847843
#
# Record 70:
#   Vehicle ID   : 70
#   Location     : (14.634679, 121.018442)
#   Speed (km/h) : 41.99
#   Battery (%)  : 96.43
#   Timestamp    : 1748847844
#
# Record 71:
#   Vehicle ID   : 71
#   Location     : (14.635245, 121.019101)
#   Speed (km/h) : 41.14
#   Battery (%)  : 96.4
#   Timestamp    : 1748847845
#
# Record 72:
#   Vehicle ID   : 72
#   Location     : (14.63555, 121.019586)
#   Speed (km/h) : 61.33
#   Battery (%)  : 96.34
#   Timestamp    : 1748847846
#
# Record 73:
#   Vehicle ID   : 73
#   Location     : (14.635987, 121.020065)
#   Speed (km/h) : 42.81
#   Battery (%)  : 96.3
#   Timestamp    : 1748847847
#
# Record 74:
#   Vehicle ID   : 74
#   Location     : (14.636572, 121.020601)
#   Speed (km/h) : 34.11
#   Battery (%)  : 96.26
#   Timestamp    : 1748847848
#
# Record 75:
#   Vehicle ID   : 75
#   Location     : (14.637103, 121.021182)
#   Speed (km/h) : 49.0
#   Battery (%)  : 96.2
#   Timestamp    : 1748847849
#
# Record 76:
#   Vehicle ID   : 76
#   Location     : (14.637547, 121.021757)
#   Speed (km/h) : 31.71
#   Battery (%)  : 96.14
#   Timestamp    : 1748847850
#
# Record 77:
#   Vehicle ID   : 77
#   Location     : (14.638059, 121.022384)
#   Speed (km/h) : 39.79
#   Battery (%)  : 96.1
#   Timestamp    : 1748847851
#
# Record 78:
#   Vehicle ID   : 78
#   Location     : (14.638539, 121.022863)
#   Speed (km/h) : 45.47
#   Battery (%)  : 96.03
#   Timestamp    : 1748847853
#
# Record 79:
#   Vehicle ID   : 79
#   Location     : (14.63912, 121.023493)
#   Speed (km/h) : 48.25
#   Battery (%)  : 95.98
#   Timestamp    : 1748847854
#
# Record 80:
#   Vehicle ID   : 80
#   Location     : (14.639589, 121.024026)
#   Speed (km/h) : 46.82
#   Battery (%)  : 95.93
#   Timestamp    : 1748847855
#
# Record 81:
#   Vehicle ID   : 81
#   Location     : (14.640148, 121.024444)
#   Speed (km/h) : 40.97
#   Battery (%)  : 95.84
#   Timestamp    : 1748847856
#
# Record 82:
#   Vehicle ID   : 82
#   Location     : (14.640527, 121.02506)
#   Speed (km/h) : 29.94
#   Battery (%)  : 95.77
#   Timestamp    : 1748847857
#
# Record 83:
#   Vehicle ID   : 83
#   Location     : (14.64109, 121.025558)
#   Speed (km/h) : 46.24
#   Battery (%)  : 95.74
#   Timestamp    : 1748847858
#
# Record 84:
#   Vehicle ID   : 84
#   Location     : (14.641522, 121.026156)
#   Speed (km/h) : 40.76
#   Battery (%)  : 95.69
#   Timestamp    : 1748847859
#
# Record 85:
#   Vehicle ID   : 85
#   Location     : (14.64199, 121.026697)
#   Speed (km/h) : 31.75
#   Battery (%)  : 95.66
#   Timestamp    : 1748847860
#
# Record 86:
#   Vehicle ID   : 86
#   Location     : (14.642514, 121.027222)
#   Speed (km/h) : 31.78
#   Battery (%)  : 95.62
#   Timestamp    : 1748847861
#
# Record 87:
#   Vehicle ID   : 87
#   Location     : (14.643038, 121.027577)
#   Speed (km/h) : 35.29
#   Battery (%)  : 95.59
#   Timestamp    : 1748847862
#
# Record 88:
#   Vehicle ID   : 88
#   Location     : (14.643516, 121.028108)
#   Speed (km/h) : 32.82
#   Battery (%)  : 95.51
#   Timestamp    : 1748847863
#
# Record 89:
#   Vehicle ID   : 89
#   Location     : (14.644, 121.028606)
#   Speed (km/h) : 48.58
#   Battery (%)  : 95.48
#   Timestamp    : 1748847864
#
# Record 90:
#   Vehicle ID   : 90
#   Location     : (14.644471, 121.029138)
#   Speed (km/h) : 39.81
#   Battery (%)  : 95.45
#   Timestamp    : 1748847865
#
# Record 91:
#   Vehicle ID   : 91
#   Location     : (14.645125, 121.029627)
#   Speed (km/h) : 45.19
#   Battery (%)  : 95.39
#   Timestamp    : 1748847866
#
# Record 92:
#   Vehicle ID   : 92
#   Location     : (14.645585, 121.03015)
#   Speed (km/h) : 46.9
#   Battery (%)  : 95.34
#   Timestamp    : 1748847867
#
# Record 93:
#   Vehicle ID   : 93
#   Location     : (14.646007, 121.030652)
#   Speed (km/h) : 40.98
#   Battery (%)  : 95.28
#   Timestamp    : 1748847868
#
# Record 94:
#   Vehicle ID   : 94
#   Location     : (14.646603, 121.031368)
#   Speed (km/h) : 54.51
#   Battery (%)  : 95.25
#   Timestamp    : 1748847869
#
# Record 95:
#   Vehicle ID   : 95
#   Location     : (14.647122, 121.032087)
#   Speed (km/h) : 48.72
#   Battery (%)  : 95.21
#   Timestamp    : 1748847870
#
# Record 96:
#   Vehicle ID   : 96
#   Location     : (14.647562, 121.032374)
#   Speed (km/h) : 31.6
#   Battery (%)  : 95.18
#   Timestamp    : 1748847871
#
# Record 97:
#   Vehicle ID   : 97
#   Location     : (14.648077, 121.032908)
#   Speed (km/h) : 32.41
#   Battery (%)  : 95.09
#   Timestamp    : 1748847872
#
# Record 98:
#   Vehicle ID   : 98
#   Location     : (14.648519, 121.033318)
#   Speed (km/h) : 49.5
#   Battery (%)  : 95.03
#   Timestamp    : 1748847874
#
# Record 99:
#   Vehicle ID   : 99
#   Location     : (14.649202, 121.033936)
#   Speed (km/h) : 26.8
#   Battery (%)  : 94.99
#   Timestamp    : 1748847875
#
# Record 100:
#   Vehicle ID   : 100
#   Location     : (14.649837, 121.034425)
#   Speed (km/h) : 22.87
#   Battery (%)  : 94.91
#   Timestamp    : 1748847876
#
# Record 101:
#   Vehicle ID   : 101
#   Location     : (14.59994, 120.984701)
#   Speed (km/h) : 24.06
#   Battery (%)  : 99.95
#   Timestamp    : 1748847877
#
# Record 102:
#   Vehicle ID   : 102
#   Location     : (14.600502, 120.985094)
#   Speed (km/h) : 35.5
#   Battery (%)  : 99.9
#   Timestamp    : 1748847878
#
# Record 103:
#   Vehicle ID   : 103
#   Location     : (14.601054, 120.985665)
#   Speed (km/h) : 41.2
#   Battery (%)  : 99.87
#   Timestamp    : 1748847879
#
# Record 104:
#   Vehicle ID   : 104
#   Location     : (14.601682, 120.986198)
#   Speed (km/h) : 24.66
#   Battery (%)  : 99.84
#   Timestamp    : 1748847880
#
# Record 105:
#   Vehicle ID   : 105
#   Location     : (14.602193, 120.986816)
#   Speed (km/h) : 55.51
#   Battery (%)  : 99.79
#   Timestamp    : 1748847881
#
# Record 106:
#   Vehicle ID   : 106
#   Location     : (14.602869, 120.987291)
#   Speed (km/h) : 60.61
#   Battery (%)  : 99.72
#   Timestamp    : 1748847882
#
# Record 107:
#   Vehicle ID   : 107
#   Location     : (14.603506, 120.987695)
#   Speed (km/h) : 46.45
#   Battery (%)  : 99.65
#   Timestamp    : 1748847883
#
# Record 108:
#   Vehicle ID   : 108
#   Location     : (14.60383, 120.988076)
#   Speed (km/h) : 50.58
#   Battery (%)  : 99.65
#   Timestamp    : 1748847884
#
# Record 109:
#   Vehicle ID   : 109
#   Location     : (14.604401, 120.988727)
#   Speed (km/h) : 37.31
#   Battery (%)  : 99.59
#   Timestamp    : 1748847885
#
# Record 110:
#   Vehicle ID   : 110
#   Location     : (14.604763, 120.989056)
#   Speed (km/h) : 56.29
#   Battery (%)  : 99.55
#   Timestamp    : 1748847886
#
# Record 111:
#   Vehicle ID   : 111
#   Location     : (14.60526, 120.98935)
#   Speed (km/h) : 43.84
#   Battery (%)  : 99.5
#   Timestamp    : 1748847887
#
# Record 112:
#   Vehicle ID   : 112
#   Location     : (14.605827, 120.989886)
#   Speed (km/h) : 26.96
#   Battery (%)  : 99.47
#   Timestamp    : 1748847888
#
# Record 113:
#   Vehicle ID   : 113
#   Location     : (14.606221, 120.99038)
#   Speed (km/h) : 34.86
#   Battery (%)  : 99.4
#   Timestamp    : 1748847889
#
# Record 114:
#   Vehicle ID   : 114
#   Location     : (14.606772, 120.990827)
#   Speed (km/h) : 30.14
#   Battery (%)  : 99.36
#   Timestamp    : 1748847890
#
# Record 115:
#   Vehicle ID   : 115
#   Location     : (14.607168, 120.991272)
#   Speed (km/h) : 38.93
#   Battery (%)  : 99.34
#   Timestamp    : 1748847891
#
# Record 116:
#   Vehicle ID   : 116
#   Location     : (14.607672, 120.991702)
#   Speed (km/h) : 59.65
#   Battery (%)  : 99.28
#   Timestamp    : 1748847892
#
# Record 117:
#   Vehicle ID   : 117
#   Location     : (14.608149, 120.992263)
#   Speed (km/h) : 38.88
#   Battery (%)  : 99.22
#   Timestamp    : 1748847893
#
# Record 118:
#   Vehicle ID   : 118
#   Location     : (14.608592, 120.992735)
#   Speed (km/h) : 34.69
#   Battery (%)  : 99.21
#   Timestamp    : 1748847894
#
# Record 119:
#   Vehicle ID   : 119
#   Location     : (14.609229, 120.9934)
#   Speed (km/h) : 24.85
#   Battery (%)  : 99.17
#   Timestamp    : 1748847895
#
# Record 120:
#   Vehicle ID   : 120
#   Location     : (14.60976, 120.994208)
#   Speed (km/h) : 45.77
#   Battery (%)  : 99.1
#   Timestamp    : 1748847897
#
# Record 121:
#   Vehicle ID   : 121
#   Location     : (14.610164, 120.994547)
#   Speed (km/h) : 38.72
#   Battery (%)  : 99.04
#   Timestamp    : 1748847898
#
# Record 122:
#   Vehicle ID   : 122
#   Location     : (14.610522, 120.994983)
#   Speed (km/h) : 32.44
#   Battery (%)  : 99.01
#   Timestamp    : 1748847899
#
# Record 123:
#   Vehicle ID   : 123
#   Location     : (14.61111, 120.995482)
#   Speed (km/h) : 56.87
#   Battery (%)  : 98.93
#   Timestamp    : 1748847900
#
# Record 124:
#   Vehicle ID   : 124
#   Location     : (14.611524, 120.996134)
#   Speed (km/h) : 40.77
#   Battery (%)  : 98.87
#   Timestamp    : 1748847901
#
# Record 125:
#   Vehicle ID   : 125
#   Location     : (14.612005, 120.996546)
#   Speed (km/h) : 29.63
#   Battery (%)  : 98.85
#   Timestamp    : 1748847902
#
# Record 126:
#   Vehicle ID   : 126
#   Location     : (14.612696, 120.996907)
#   Speed (km/h) : 49.26
#   Battery (%)  : 98.79
#   Timestamp    : 1748847903
#
# Record 127:
#   Vehicle ID   : 127
#   Location     : (14.613147, 120.997347)
#   Speed (km/h) : 33.49
#   Battery (%)  : 98.76
#   Timestamp    : 1748847904
#
# Record 128:
#   Vehicle ID   : 128
#   Location     : (14.613564, 120.997874)
#   Speed (km/h) : 40.49
#   Battery (%)  : 98.71
#   Timestamp    : 1748847905
#
# Record 129:
#   Vehicle ID   : 129
#   Location     : (14.613973, 120.998317)
#   Speed (km/h) : 37.61
#   Battery (%)  : 98.64
#   Timestamp    : 1748847906
#
# Record 130:
#   Vehicle ID   : 130
#   Location     : (14.614376, 120.998827)
#   Speed (km/h) : 45.01
#   Battery (%)  : 98.58
#   Timestamp    : 1748847907
#
# Record 131:
#   Vehicle ID   : 131
#   Location     : (14.61493, 120.99926)
#   Speed (km/h) : 23.31
#   Battery (%)  : 98.52
#   Timestamp    : 1748847908
#
# Record 132:
#   Vehicle ID   : 132
#   Location     : (14.615249, 120.999598)
#   Speed (km/h) : 32.37
#   Battery (%)  : 98.47
#   Timestamp    : 1748847909
#
# Record 133:
#   Vehicle ID   : 133
#   Location     : (14.615659, 121.000162)
#   Speed (km/h) : 42.6
#   Battery (%)  : 98.45
#   Timestamp    : 1748847910
#
# Record 134:
#   Vehicle ID   : 134
#   Location     : (14.616038, 121.000596)
#   Speed (km/h) : 39.34
#   Battery (%)  : 98.4
#   Timestamp    : 1748847911
#
# Record 135:
#   Vehicle ID   : 135
#   Location     : (14.616499, 121.001197)
#   Speed (km/h) : 31.4
#   Battery (%)  : 98.36
#   Timestamp    : 1748847912
#
# Record 136:
#   Vehicle ID   : 136
#   Location     : (14.616886, 121.00175)
#   Speed (km/h) : 48.36
#   Battery (%)  : 98.28
#   Timestamp    : 1748847913
#
# Record 137:
#   Vehicle ID   : 137
#   Location     : (14.617307, 121.002308)
#   Speed (km/h) : 15.28
#   Battery (%)  : 98.23
#   Timestamp    : 1748847915
#
# Record 138:
#   Vehicle ID   : 138
#   Location     : (14.617746, 121.002816)
#   Speed (km/h) : 43.71
#   Battery (%)  : 98.19
#   Timestamp    : 1748847916
#
# Record 139:
#   Vehicle ID   : 139
#   Location     : (14.618272, 121.00335)
#   Speed (km/h) : 51.68
#   Battery (%)  : 98.15
#   Timestamp    : 1748847917
#
# Record 140:
#   Vehicle ID   : 140
#   Location     : (14.618729, 121.00389)
#   Speed (km/h) : 35.12
#   Battery (%)  : 98.1
#   Timestamp    : 1748847918
#
# Record 141:
#   Vehicle ID   : 141
#   Location     : (14.619436, 121.004477)
#   Speed (km/h) : 42.9
#   Battery (%)  : 98.06
#   Timestamp    : 1748847919
#
# Record 142:
#   Vehicle ID   : 142
#   Location     : (14.619895, 121.004773)
#   Speed (km/h) : 52.01
#   Battery (%)  : 98.03
#   Timestamp    : 1748847920
#
# Record 143:
#   Vehicle ID   : 143
#   Location     : (14.62036, 121.005275)
#   Speed (km/h) : 21.29
#   Battery (%)  : 97.95
#   Timestamp    : 1748847921
#
# Record 144:
#   Vehicle ID   : 144
#   Location     : (14.620838, 121.005858)
#   Speed (km/h) : 43.27
#   Battery (%)  : 97.94
#   Timestamp    : 1748847922
#
# Record 145:
#   Vehicle ID   : 145
#   Location     : (14.621415, 121.00621)
#   Speed (km/h) : 42.36
#   Battery (%)  : 97.87
#   Timestamp    : 1748847923
#
# Record 146:
#   Vehicle ID   : 146
#   Location     : (14.621874, 121.006773)
#   Speed (km/h) : 43.38
#   Battery (%)  : 97.77
#   Timestamp    : 1748847924
#
# Record 147:
#   Vehicle ID   : 147
#   Location     : (14.622399, 121.007227)
#   Speed (km/h) : 41.82
#   Battery (%)  : 97.74
#   Timestamp    : 1748847925
#
# Record 148:
#   Vehicle ID   : 148
#   Location     : (14.622813, 121.007734)
#   Speed (km/h) : 48.3
#   Battery (%)  : 97.7
#   Timestamp    : 1748847926
#
# Record 149:
#   Vehicle ID   : 149
#   Location     : (14.623346, 121.008338)
#   Speed (km/h) : 44.79
#   Battery (%)  : 97.66
#   Timestamp    : 1748847927
#
# Record 150:
#   Vehicle ID   : 150
#   Location     : (14.623748, 121.008794)
#   Speed (km/h) : 37.3
#   Battery (%)  : 97.6
#   Timestamp    : 1748847928

# %%
# !pip install pandas folium
# Out:
# Requirement already satisfied: pandas in c:\users\jomax\anaconda3\lib\site-packages (2.2.2)
# Collecting folium
#   Downloading folium-0.19.6-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jomax\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jomax\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jomax\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jomax\anaconda3\lib\site-packages (from pandas) (2023.3)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\jomax\anaconda3\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in c:\users\jomax\anaconda3\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\jomax\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jomax\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: six>=1.5 in c:\users\jomax\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jomax\anaconda3\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jomax\anaconda3\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jomax\anaconda3\lib\site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jomax\anaconda3\lib\site-packages (from requests->folium) (2025.4.26)
# Downloading folium-0.19.6-py2.py3-none-any.whl (112 kB)
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Installing collected packages: branca, folium
# Successfully installed branca-0.8.1 folium-0.19.6

# %%
from datetime import datetime
import pandas as pd

# Get the total number of records from the smart contract
total = contract.functions.getRecordCount().call()
print(f"📦 Total records stored in contract: {total}")

# Retrieve all records and store them in a list
records = []

for i in range(total):
    record = contract.functions.getRecord(i).call()
    records.append({
        "Vehicle ID": record[0],
        "Latitude": record[1],
        "Longitude": record[2],
        "Speed (km/h)": record[3],
        "Battery (%)": record[4],
        "Timestamp": datetime.fromtimestamp(record[5])  # convert UNIX to readable format
    })

# Create the DataFrame
df = pd.DataFrame(records)

# Optional: Preview the DataFrame
print(df.head())
# Out:
# 📦 Total records stored in contract: 150
#   Vehicle ID   Latitude   Longitude Speed (km/h) Battery (%)  \
# 0          1  14.599986  120.984765        44.97       99.92
# 1          2  14.600463  120.985423        37.66       99.85
# 2          3  14.601017  120.985876        35.31       99.81
# 3          4  14.601326  120.986204        42.42       99.77
# 4          5  14.601857  120.986613        29.87       99.75
#
#             Timestamp
# 0 2025-06-02 15:35:50
# 1 2025-06-02 15:35:51
# 2 2025-06-02 15:35:52
# 3 2025-06-02 15:35:53
# 4 2025-06-02 15:35:54

# %%
import folium

# Center the map on the first vehicle's location
start_coords = [df.loc[0, "Latitude"], df.loc[0, "Longitude"]]
vehicle_map = folium.Map(location=start_coords, zoom_start=16)

# Add vehicle markers
for _, row in df.iterrows():
    popup_info = (
        f"Vehicle ID: {row['Vehicle ID']}<br>"
        f"Speed: {row['Speed (km/h)']} km/h<br>"
        f"Battery: {row['Battery (%)']}%<br>"
        f"Timestamp: {row['Timestamp']}"
    )
    folium.Marker(
        location=[row["Latitude"], row["Longitude"]],
        popup=popup_info,
        tooltip=f"Vehicle {row['Vehicle ID']}"
    ).add_to(vehicle_map)

# Show or save map
vehicle_map  # If you're in Jupyter, this shows the map
# vehicle_map.save("vehicle_map.html")  # Uncomment to save to HTML
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_238d23bb1b9e386a1c8b20accbed6f6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_238d23bb1b9e386a1c8b20accbed6f6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_238d23bb1b9e386a1c8b20accbed6f6a = L.map(
#                 &quot;map_238d23bb1b9e386a1c8b20accbed6f6a&quot;,
#                 {
#                     center: [14.599986, 120.984765],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_311dfd38a884cfa75b0eab5e42298f00 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_311dfd38a884cfa75b0eab5e42298f00.addTo(map_238d23bb1b9e386a1c8b20accbed6f6a);
#
#
#             var marker_7c2bb8a5e927db47f872944fc1194d3f = L.marker(
#                 [14.599986, 120.984765],
#                 {
# }
#             ).addTo(map_238d23bb1b9e386a1c8b20accbed6f6a);
#
#
#         var popup_8d7efac82c6232cbd0480b3cdb3bab9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e02344060125f9afa287c478fb09e4b6 = $(`&lt;div id=&quot;html_e02344060125f9afa287c478fb09e4b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle ID: 1&lt;br&gt;Speed: 44.97 km/h&lt;br&gt;Battery: 99.92%&lt;br&gt;Timestamp: 2025-06-02 15:35:50&lt;/div&gt;`)[0];
#                 popup_8d7efac82c6232cbd0480b3cdb3bab9f.setContent(html_e02344060125f9afa287c478fb09e4b6);
#
#
#
#         marker_7c2bb8a5e927db47f872944fc1194d3f.bindPopup(popup_8d7efac82c6232cbd0480b3cdb3bab9f)
#         ;
#
#
#
#
#             marker_7c2bb8a5e927db47f872944fc1194d3f.bindTooltip(
#                 `&lt;div&gt;
#                      Vehicle 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_55e1458709c3ff66c736c45b4945eeaa = L.marker(
#                 [14.600463, 120.985423],
#                 {
# }
#             ).addTo(map_238d23bb1b9e386a1c8b20accbed6f6a);
#
#
#         var popup_24605049b6e49daf6825ffb9a173827c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8f106c95248f067c4554b2d8638ff1d = $(`&lt;div id=&quot;html_a8f106c95248f067c4554b2d8638ff1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle ID: 2&lt;br&gt;Speed: 37.66 km/h&lt;br&gt;Battery: 99.85%&lt;br&gt;Timestamp: 2025-06-02 15:35:51&lt;/div&gt;`)[0];
#                 popup_24605049b6e49daf6825ffb9a173827c.setContent(html_a8f106c95248f067c4554b2d8638ff1d);
#
#
#
#         marker_55e1458709c3ff66c736c45b4945eeaa.bindPopup(popup_24605049b6e49daf6825ffb9a173827c)
#         ;
#
#
#
#
#             marker_55e1458709c3ff66c736c45b4945eeaa.bindTooltip(
#                 `&lt;div&gt;
#                      Vehicle 2
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_1c3ead19517427b9abd3b8650ff6ae53 = L.marker(
#                 [14.601017, 120.985876],
#                 {
# }
#             ).addTo(map_238d23bb1b9e386a1c8b20accbed6f6a);
#
#
#         var popup_b93593ac8710ce0d7c458b07f947281f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7d0f904d4c86b3297ae07996fd1ffe9 = $(`&lt;div id=&quot;html_c7d0f904d4c86b3297ae07996fd1ffe9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle ID: 3&lt;br&gt;Speed: 35.31 km/h&lt;br&gt;Battery: 99.81%&lt;br&gt;Timestamp: 2025-06-02 15:35:52&lt;/div&gt;`)[0];
#                 popup_b93593ac8710ce0d7c458b07f947281f.setContent(html_c7d0f904d4c86b3297ae07996fd1ffe9);
#
#
#
#         marker_1c3ead19517427b9abd3b8650ff6ae53.bindPopup(popup_b93593ac8710ce0d7c458b07f947281f)
#         ;
#
#
#
#
#             marker_1c3ead19517427b9abd3b8650ff6ae53.bindTooltip(
#                 `&lt;div&gt;
#                      Vehicle 3
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_3bcd601676993b7c824d0e82a42f30fa = L.marker(
#                 [14.601326, 120.986204],
#                 {
# }
#             ).addTo(map_238d23bb1b9e386a1c8b20accbed6f6a);
#
#
#         var popup_8a9c506388b32358881f179ed8d14bcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_226913448d480a35b28d1b676da71d54 = $(`&lt;div id=&quot;html_226913448d480a35b28d1b676da71d54&quot; style=&quot;width: 100.0%; height: 100.0%;&q
